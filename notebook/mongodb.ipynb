# %%
import pandas as pd
import pymongo
from dotenv import load_dotenv
import os

# %%
df = pd.read_csv('Visadataset.csv')
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
data = df.to_dict('records')

# %%
load_dotenv()
DB_NAME = "usVisaDB"
COLLECTION_NAME = "usVisaCollection"
url = os.getenv("MONGODB_URL")

# %%
client = pymongo.MongoClient(url)
database = client[DB_NAME]
data_collection = database[COLLECTION_NAME]
data_collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('661ffc3aa64da1dfbb52cd34'), ObjectId('661ffc3aa64da1dfbb52cd35'), ObjectId('661ffc3aa64da1dfbb52cd36'), ObjectId('661ffc3aa64da1dfbb52cd37'), ObjectId('661ffc3aa64da1dfbb52cd38'), ObjectId('661ffc3aa64da1dfbb52cd39'), ObjectId('661ffc3aa64da1dfbb52cd3a'), ObjectId('661ffc3aa64da1dfbb52cd3b'), ObjectId('661ffc3aa64da1dfbb52cd3c'), ObjectId('661ffc3aa64da1dfbb52cd3d'), ObjectId('661ffc3aa64da1dfbb52cd3e'), ObjectId('661ffc3aa64da1dfbb52cd3f'), ObjectId('661ffc3aa64da1dfbb52cd40'), ObjectId('661ffc3aa64da1dfbb52cd41'), ObjectId('661ffc3aa64da1dfbb52cd42'), ObjectId('661ffc3aa64da1dfbb52cd43'), ObjectId('661ffc3aa64da1dfbb52cd44'), ObjectId('661ffc3aa64da1dfbb52cd45'), ObjectId('661ffc3aa64da1dfbb52cd46'), ObjectId('661ffc3aa64da1dfbb52cd47'), ObjectId('661ffc3aa64da1dfbb52cd48'), ObjectId('661ffc3aa64da1dfbb52cd49'), ObjectId('661ffc3aa64da1dfbb52cd4a'), ObjectId('661ffc3aa64da1dfbb52cd4b'), ObjectId('661ffc3aa64da1dfbb52cd4c'), ObjectId('661ffc3aa64da1dfbb52cd4d'), ObjectId('661ffc3aa64da1dfbb52cd4e'), ObjectId('661ffc3aa64da1dfbb52cd4f'), ObjectId('661ffc3aa64da1dfbb52cd50'), ObjectId('661ffc3aa64da1dfbb52cd51'), ObjectId('661ffc3aa64da1dfbb52cd52'), ObjectId('661ffc3aa64da1dfbb52cd53'), ObjectId('661ffc3aa64da1dfbb52cd54'), ObjectId('661ffc3aa64da1dfbb52cd55'), ObjectId('661ffc3aa64da1dfbb52cd56'), ObjectId('661ffc3aa64da1dfbb52cd57'), ObjectId('661ffc3aa64da1dfbb52cd58'), ObjectId('661ffc3aa64da1dfbb52cd59'), ObjectId('661ffc3aa64da1dfbb52cd5a'), ObjectId('661ffc3aa64da1dfbb52cd5b'), ObjectId('661ffc3aa64da1dfbb52cd5c'), ObjectId('661ffc3aa64da1dfbb52cd5d'), ObjectId('661ffc3aa64da1dfbb52cd5e'), ObjectId('661ffc3aa64da1dfbb52cd5f'), ObjectId('661ffc3aa64da1dfbb52cd60'), ObjectId('661ffc3aa64da1dfbb52cd61'), ObjectId('661ffc3aa64da1dfbb52cd62'), ObjectId('661ffc3aa64da1dfbb52cd63'), ObjectId('661ffc3aa64da1dfbb52cd64'), ObjectId('661ffc3aa64da1dfbb52cd65'), ObjectId('661ffc3aa64da1dfbb52cd66'), ObjectId('661ffc3aa64da1dfbb52cd67'), ObjectId('661ffc3aa64da1dfbb52cd68'), ObjectId('661ffc3aa64da1dfbb52cd69'), ObjectId('661ffc3aa64da1dfbb52cd6a'), ObjectId('661ffc3aa64da1dfbb52cd6b'), ObjectId('661ffc3aa64da1dfbb52cd6c'), ObjectId('661ffc3aa64da1dfbb52cd6d'), ObjectId('661ffc3aa64da1dfbb52cd6e'), ObjectId('661ffc3aa64da1dfbb52cd6f'), ObjectId('661ffc3aa64da1dfbb52cd70'), ObjectId('661ffc3aa64da1dfbb52cd71'), ObjectId('661ffc3aa64da1dfbb52cd72'), ObjectId('661ffc3aa64da1dfbb52cd73'), ObjectId('661ffc3aa64da1dfbb52cd74'), ObjectId('661ffc3aa64da1dfbb52cd75'), ObjectId('661ffc3aa64da1dfbb52cd76'), ObjectId('661ffc3aa64da1dfbb52cd77'), ObjectId('661ffc3aa64da1dfbb52cd78'), ObjectId('661ffc3aa64da1dfbb52cd79'), ObjectId('661ffc3aa64da1dfbb52cd7a'), ObjectId('661ffc3aa64da1dfbb52cd7b'), ObjectId('661ffc3aa64da1dfbb52cd7c'), ObjectId('661ffc3aa64da1dfbb52cd7d'), ObjectId('661ffc3aa64da1dfbb52cd7e'), ObjectId('661ffc3aa64da1dfbb52cd7f'), ObjectId('661ffc3aa64da1dfbb52cd80'), ObjectId('661ffc3aa64da1dfbb52cd81'), ObjectId('661ffc3aa64da1dfbb52cd82'), ObjectId('661ffc3aa64da1dfbb52cd83'), ObjectId('661ffc3aa64da1dfbb52cd84'), ObjectId('661ffc3aa64da1dfbb52cd85'), ObjectId('661ffc3aa64da1dfbb52cd86'), ObjectId('661ffc3aa64da1dfbb52cd87'), ObjectId('661ffc3aa64da1dfbb52cd88'), ObjectId('661ffc3aa64da1dfbb52cd89'), ObjectId('661ffc3aa64da1dfbb52cd8a'), ObjectId('661ffc3aa64da1dfbb52cd8b'), ObjectId('661ffc3aa64da1dfbb52cd8c'), ObjectId('661ffc3aa64da1dfbb52cd8d'), ObjectId('661ffc3aa64da1dfbb52cd8e'), ObjectId('661ffc3aa64da1dfbb52cd8f'), ObjectId('661ffc3aa64da1dfbb52cd90'), ObjectId('661ffc3aa64da1dfbb52cd91'), ObjectId('661ffc3aa64da1dfbb52cd92'), ObjectId('661ffc3aa64da1dfbb52cd93'), ObjectId('661ffc3aa64da1dfbb52cd94'), ObjectId('661ffc3aa64da1dfbb52cd95'), ObjectId('661ffc3aa64da1dfbb52cd96'), ObjectId('661ffc3aa64da1dfbb52cd97'), ObjectId('661ffc3aa64da1dfbb52cd98'), ObjectId('661ffc3aa64da1dfbb52cd99'), ObjectId('661ffc3aa64da1dfbb52cd9a'), ObjectId('661ffc3aa64da1dfbb52cd9b'), ObjectId('661ffc3aa64da1dfbb52 ...

# %%
df = pd.DataFrame(list(data_collection.find()))

# %%
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  661ffc3aa64da1dfbb52cd34  EZYV01      Asia           High School
# 1  661ffc3aa64da1dfbb52cd35  EZYV02      Asia              Master's
# 2  661ffc3aa64da1dfbb52cd36  EZYV03      Asia            Bachelor's
# 3  661ffc3aa64da1dfbb52cd37  EZYV04      Asia            Bachelor's
# 4  661ffc3aa64da1dfbb52cd38  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                 West         592.2029         Hour                  Y
# 1            Northeast       83425.6500         Year                  Y
# 2                 West      122996.8600         Year                  Y
# 3                 West       83434.0300         Year                  Y
# 4                South      149907.3900         Year                  Y
#
#   case_status
# 0      Denied
# 1   Certified
# 2      Denied
# 3      Denied
# 4   Certified

# %%
if "_id" in df.columns:
    df.drop("_id", axis=1, inplace=True)

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified
